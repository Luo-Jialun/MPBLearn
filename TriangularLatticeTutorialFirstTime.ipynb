# %% [markdown]
# ## This is following the tutorial from
# https://mpb.readthedocs.io/en/latest/Python_Tutorial/

# %%
import math
import meep as mp
from meep import mpb

# %%
boundary_k_points = [mp.Vector3(),               # Gamma
              mp.Vector3(y=0.5),          # M
              mp.Vector3(-1 / 3, 1 / 3),  # K
              mp.Vector3()]               # Gamma

k_points = mp.interpolate(4, boundary_k_points)
num_bands = 8
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                                 basis1=mp.Vector3(math.sqrt(3) / 2, 0.5),
                                 basis2=mp.Vector3(math.sqrt(3) / 2, -0.5))
resolution = 32
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)

ms.run_tm()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.004987478256225586
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.06114530563354492
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0711319, 0.538981, 0.559429, 0.617095, 0.834123, 0.839462, 0.988272, 1.08637
# elapsed time for k point: 0.02837991714477539
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.138898, 0.508574, 0.556587, 0.65398, 0.825087, 0.84452, 0.968999, 1.05281
# elapsed time for k point: 0.02498340606689453
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198939, 0.479631, 0.553145, 0.693119, 0.813353, 0.850964, 0.932869, 1.02598
# elapsed time for k point: 0.02527618408203125
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.244064, 0.4557, 0.550414, 0.730028, 0.80289, 0.856372, 0.891379, 1.01409
# elapsed time for k point: 0.022952556610107422
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.262015, 0.445331, 0.549383, 0.749186, 0.797864, 0.85849, 0.870609, 1.01087
# elapsed time for k point: 0.022403240203857422
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.262984, 0.4475, 0.545804, 0.752448, 0.797093, 0.860461, 0.870245, 0.99895
# elapsed time for k point: 0.029272794723510742
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.265671, 0.453801, 0.535912, 0.761319, 0.795166, 0.866056, 0.869135, 0.973413
# elapsed time for k point: 0.0518651008605957
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.269404, 0.463648, 0.52172, 0.773443, 0.792931, 0.867201, 0.874681, 0.94487
# elapsed time for k point: 0.02149820327758789
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.273, 0.476141, 0.505606, 0.78524, 0.791235, 0.864672, 0.885801, 0.918597
# elapsed time for k point: 0.018415212631225586
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.27469, 0.489984, 0.490239, 0.79072, 0.790832, 0.863041, 0.899109, 0.89925
# elapsed time for k point: 0.01992487907409668
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.2632, 0.47091, 0.51804, 0.764413, 0.795091, 0.864427, 0.896871, 0.932925
# elapsed time for k point: 0.019693374633789062
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.222593, 0.476537, 0.539917, 0.715636, 0.806516, 0.856013, 0.929969, 0.977199
# elapsed time for k point: 0.021221160888671875
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.15856, 0.501245, 0.552927, 0.666818, 0.82116, 0.846938, 0.963589, 1.03113
# elapsed time for k point: 0.025985002517700195
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0819275, 0.534465, 0.558896, 0.622523, 0.832982, 0.840137, 0.98638, 1.08149
# elapsed time for k point: 0.030637502670288086
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.06064414978027344
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27469022601674825 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4453310810690976 at Vector3<0.0, 0.5, 0.0> to 0.56051814419561 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4902389149689675 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607962931303 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960878330009 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678293 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764965163 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511183597798 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948534061807 at Vector3<0.0, 0.0, 0.0> to 0.867200926636393 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8691349976047842 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291098556084 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210421 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.098318359244588 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022601674825) to band 2 (0.4453310810690976), 47.398834832537624%
# Gap from band 3 (0.5605607962931303) to band 4 (0.5932960878330009), 5.674064433850925%
# Gap from band 4 (0.7907195975678293) to band 5 (0.7908320764965163), 0.014223870206907562%
# Gap from band 5 (0.8374511183597798) to band 6 (0.8375948534061807), 0.017161922576886045%
# Gap from band 6 (0.867200926636393) to band 7 (0.8691349976047842), 0.22277612775147676%
# total elapsed time for run: 0.49448513984680176
# done

# %%
def first_tm_gap(r):
    ms.geometry = [mp.Cylinder(r, material=mp.Medium(epsilon=12))]
    ms.run_tm()
    
    return -1 * ms.retrieve_gap(1) # return the gap from TM band 1 to TM band 2

# %%
ms.num_bands = 2
ms.mesh_size = 7

# %%
from scipy.optimize import minimize_scalar

result = minimize_scalar(first_tm_gap, method='bounded', bounds=[0.1, 0.5], options={'xatol': 0.1})
print("radius at maximum: {}".format(result.x))
print("gap size at maximum: {}".format(result.fun * -1))
# Out:
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.252786, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0029985904693603516
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 11 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.465731
# elapsed time for k point: 0.0032956600189208984
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 12 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0608853, 0.455205
# elapsed time for k point: 0.004996299743652344
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.119259, 0.431605
# elapsed time for k point: 0.002628326416015625
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.17191, 0.404132
# elapsed time for k point: 0.0022590160369873047
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.213092, 0.378935
# elapsed time for k point: 0.0022509098052978516
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.230411, 0.36716
# elapsed time for k point: 0.0022547245025634766
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.231338, 0.368888
# elapsed time for k point: 0.0018696784973144531
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.233922, 0.373916
# elapsed time for k point: 0.002254009246826172
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.237544, 0.381792
# elapsed time for k point: 0.0022411346435546875
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.241077, 0.391837
# elapsed time for k point: 0.002236604690551758
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 11 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.242759, 0.403108
# elapsed time for k point: 0.004487752914428711
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 18 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.231351, 0.389851
# elapsed time for k point: 0.0074155330657958984
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.193192, 0.400294
# elapsed time for k point: 0.0022554397583007812
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.136354, 0.425264
# elapsed time for k point: 0.00225067138671875
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0701479, 0.452269
# elapsed time for k point: 0.002627134323120117
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 7 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.465732
# elapsed time for k point: 0.0020623207092285156
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.24275923024827312 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.36715955722086546 at Vector3<0.0, 0.5, 0.0> to 0.46573193709511634 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.24275923024827312) to band 2 (0.36715955722086546), 40.79242336140921%
# total elapsed time for run: 0.05102181434631348
# done
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.347214, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0019440650939941406
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 12 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.376047
# elapsed time for k point: 0.0034301280975341797
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 15 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0477425, 0.366526
# elapsed time for k point: 0.006042957305908203
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 8 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.0944768, 0.343968
# elapsed time for k point: 0.003371000289916992
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.138837, 0.31548
# elapsed time for k point: 0.0026226043701171875
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.177681, 0.286024
# elapsed time for k point: 0.002276182174682617
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.197617, 0.269225
# elapsed time for k point: 0.002251863479614258
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.198586, 0.270699
# elapsed time for k point: 0.001878976821899414
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.201331, 0.275023
# elapsed time for k point: 0.002245664596557617
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.205314, 0.281916
# elapsed time for k point: 0.0022530555725097656
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.209416, 0.290945
# elapsed time for k point: 0.0022535324096679688
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.211492, 0.301575
# elapsed time for k point: 0.0022590160369873047
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 9 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.197206, 0.29391
# elapsed time for k point: 0.003741025924682617
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.158018, 0.3116
# elapsed time for k point: 0.002249002456665039
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.108543, 0.338312
# elapsed time for k point: 0.0022623538970947266
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0550658, 0.363897
# elapsed time for k point: 0.0026311874389648438
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 8 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.375946
# elapsed time for k point: 0.0023157596588134766
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.21149153764534387 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.26922455687636854 at Vector3<0.0, 0.5, 0.0> to 0.37604651458944516 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.21149153764534387) to band 2 (0.26922455687636854), 24.019590726816013%
# total elapsed time for run: 0.04686546325683594
# done
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.194427, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0014047622680664062
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 35 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.573653
# elapsed time for k point: 0.009327888488769531
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 17 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0723653, 0.548491
# elapsed time for k point: 0.006854057312011719
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.141304, 0.517438
# elapsed time for k point: 0.003000020980834961
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.202349, 0.488519
# elapsed time for k point: 0.002252340316772461
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.248137, 0.464773
# elapsed time for k point: 0.0022504329681396484
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.266297, 0.454523
# elapsed time for k point: 0.0022530555725097656
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.267275, 0.456771
# elapsed time for k point: 0.0018756389617919922
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.269988, 0.463304
# elapsed time for k point: 0.00225067138671875
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.273756, 0.473523
# elapsed time for k point: 0.0022478103637695312
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.277382, 0.486503
# elapsed time for k point: 0.0029897689819335938
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 10 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.279087, 0.500739
# elapsed time for k point: 0.004136562347412109
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 19 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.267493, 0.480786
# elapsed time for k point: 0.008011579513549805
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.226367, 0.485648
# elapsed time for k point: 0.002257823944091797
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.161301, 0.510106
# elapsed time for k point: 0.0027391910552978516
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0833481, 0.543818
# elapsed time for k point: 0.003019094467163086
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 12 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.57406
# elapsed time for k point: 0.0033392906188964844
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2790871318318782 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4545233891590931 at Vector3<0.0, 0.5, 0.0> to 0.5740602017210624 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2790871318318782) to band 2 (0.4545233891590931), 47.82817375362424%
# total elapsed time for run: 0.06089949607849121
# done
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 7.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.158359, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0012660026550292969
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 9 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.595606
# elapsed time for k point: 0.0027098655700683594
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0810781, 0.58597
# elapsed time for k point: 0.004075050354003906
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.158569, 0.565321
# elapsed time for k point: 0.002701997756958008
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.227497, 0.542232
# elapsed time for k point: 0.0026466846466064453
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.279263, 0.521818
# elapsed time for k point: 0.0022706985473632812
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.29971, 0.512709
# elapsed time for k point: 0.0022695064544677734
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.300784, 0.515616
# elapsed time for k point: 0.0018982887268066406
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.303762, 0.524127
# elapsed time for k point: 0.0018832683563232422
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.307893, 0.537626
# elapsed time for k point: 0.002283334732055664
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.311867, 0.55513
# elapsed time for k point: 0.002619504928588867
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 10 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.313735, 0.574977
# elapsed time for k point: 0.0041348934173583984
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 11 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.300888, 0.544244
# elapsed time for k point: 0.0045316219329833984
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.254641, 0.541534
# elapsed time for k point: 0.002634763717651367
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.181117, 0.559689
# elapsed time for k point: 0.0026657581329345703
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 7 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0934014, 0.583261
# elapsed time for k point: 0.0030205249786376953
# solve_kpoint (0,0,0):
# Solving for bands 2 to 2...
# Finished solving for bands 2 to 2 after 8 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.595606
# elapsed time for k point: 0.002335071563720703
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.31373500489068457 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.5127086406157524 at Vector3<0.0, 0.5, 0.0> to 0.5956060303470344 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.31373500489068457) to band 2 (0.5127086406157524), 48.15177339844839%
# total elapsed time for run: 0.04688096046447754
# done
# radius at maximum: 0.15835921350012622
# gap size at maximum: 48.15177339844839

# %%
ms.mesh_size = 3

# %% [markdown]
# As another example, let's construct a structure with a complete 2d gap (i.e., in both TE and TM polarizations), in a somewhat unusual way: using a dielectric structure. An anisotropic dielectric presents a different dielectric constant depending upon the direction of the electric field, and can be used in this case to make the TE and TM polarizations "see" different structures.
#
# We already know that the triangular lattice of rods has a gap for TM light, but not for TE light. The dual structure, a triangular lattice of holes, has a gap for TE light but not for TM light at least for the small radii we will consider. Using an anisotropic dielectric, we can make both of these structures simultaneously, with each polarization seeing the structure that gives it a gap.

# %%
ms.geometry = [mp.Cylinder(radius=0.3, material=mp.Medium(epsilon_diag=mp.Vector3(1, 1, 12)))]
ms.default_material = mp.Medium(epsilon_diag=mp.Vector3(12, 12, 1))
ms.num_bands = 8
ms.run()  # just use run, instead of run_te or run_tm, to find the complete gap
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.3, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0030312538146972656
# solve_kpoint (0,0,0):
# Solving for bands 3 to 8...
# Finished solving for bands 3 to 8 after 37 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.366827, 0.411783, 0.411791, 0.418096, 0.418405, 0.420087
# elapsed time for k point: 0.2101573944091797
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 23 iterations.
# freqs:, 2, 0, 0.1, 0, 0.11547, 0.0441896, 0.0536199, 0.360487, 0.402618, 0.408185, 0.410407, 0.417206, 0.426041
# elapsed time for k point: 0.07983136177062988
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 21 iterations.
# freqs:, 3, 0, 0.2, 0, 0.23094, 0.0877462, 0.10555, 0.344777, 0.380631, 0.384787, 0.406933, 0.414699, 0.443127
# elapsed time for k point: 0.05660605430603027
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 20 iterations.
# freqs:, 4, 0, 0.3, 0, 0.34641, 0.129515, 0.153576, 0.31993, 0.353232, 0.365974, 0.402875, 0.411801, 0.464478
# elapsed time for k point: 0.05384492874145508
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 23 iterations.
# freqs:, 5, 0, 0.4, 0, 0.46188, 0.166045, 0.193205, 0.290557, 0.326212, 0.356396, 0.399756, 0.409594, 0.487851
# elapsed time for k point: 0.08149480819702148
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 28 iterations.
# freqs:, 6, 0, 0.5, 0, 0.57735, 0.183995, 0.211319, 0.274503, 0.312387, 0.353526, 0.398599, 0.408782, 0.506848
# elapsed time for k point: 0.09358072280883789
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 19 iterations.
# freqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.185631, 0.212253, 0.275201, 0.313955, 0.34717, 0.395197, 0.414829, 0.505217
# elapsed time for k point: 0.0517277717590332
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 19 iterations.
# freqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.190254, 0.214876, 0.277281, 0.318531, 0.333039, 0.385943, 0.428099, 0.500855
# elapsed time for k point: 0.07069158554077148
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 18 iterations.
# freqs:, 9, -0.2, 0.4, 0, 0.61101, 0.196936, 0.218606, 0.280692, 0.316744, 0.32576, 0.37298, 0.443117, 0.495146
# elapsed time for k point: 0.08850288391113281
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 16 iterations.
# freqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.20377, 0.222322, 0.285358, 0.301555, 0.335097, 0.358727, 0.456311, 0.490807
# elapsed time for k point: 0.04503750801086426
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 16 iterations.
# freqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.207153, 0.224132, 0.291145, 0.291229, 0.345781, 0.345906, 0.4618, 0.493847
# elapsed time for k point: 0.0687570571899414
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 27 iterations.
# freqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.189165, 0.211786, 0.298296, 0.3058, 0.335309, 0.368741, 0.451744, 0.476326
# elapsed time for k point: 0.09377694129943848
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 19 iterations.
# freqs:, 13, -0.2, 0.2, 0, 0.4, 0.148583, 0.173639, 0.323215, 0.330149, 0.34923, 0.388947, 0.438298, 0.458487
# elapsed time for k point: 0.05151104927062988
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 20 iterations.
# freqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.101032, 0.120964, 0.341813, 0.368258, 0.374759, 0.402729, 0.427629, 0.441145
# elapsed time for k point: 0.10405611991882324
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 20 iterations.
# freqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0509852, 0.0618099, 0.358715, 0.400022, 0.403054, 0.409764, 0.420966, 0.425827
# elapsed time for k point: 0.07117247581481934
# solve_kpoint (0,0,0):
# Solving for bands 3 to 8...
# Finished solving for bands 3 to 8 after 20 iterations.
# freqs:, 16, 0, 0, 0, 0, 0, 0, 0.366827, 0.411783, 0.411791, 0.418096, 0.418405, 0.420087
# elapsed time for k point: 0.04062008857727051
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.20715288761357206 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.22413162481424917 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 3 range: 0.2745028221131958 at Vector3<0.0, 0.5, 0.0> to 0.3668269774738644 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.29122866687829646 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4117834104454652 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.3257595812178771 at Vector3<-0.2, 0.39999999999999997, 0.0> to 0.411790889028125 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.3459056603043377 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4180958423008153 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.4087819157643429 at Vector3<0.0, 0.5, 0.0> to 0.461800351090824 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 0.42008722259325787 at Vector3<0.0, 0.0, 0.0> to 0.5068478128985546 at Vector3<0.0, 0.5, 0.0>
# Gap from band 2 (0.22413162481424917) to band 3 (0.2745028221131958), 20.203657252053443%
# total elapsed time for run: 1.269171953201294
# done

# %%
ms.geometry_lattice = mp.Lattice(size=mp.Vector3(5, 5))
ms.geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))] # specify the initial geometry
ms.geometry = mp.geometric_objects_lattice_duplicates(ms.geometry_lattice, ms.geometry) #duplicate the geometry over lattice points

ms.geometry.append(mp.Cylinder(0.2, material=mp.air))
ms.k_points = [mp.Vector3(0.5, 0.5)]
ms.num_bands = 50

# %%
ms.run_tm()
# Out:
# Initializing eigensolver data
# Computing 50 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 160 x 160 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (5, 0, 0)
#      (0, 5, 0)
#      (0, 0, 1)
# Cell volume = 25
# Reciprocal lattice vectors (/ 2 pi):
#      (0.2, -0, 0)
#      (-0, 0.2, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (2,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 5 and 33 object nodes (vs. 26 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.1274576187133789
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 32 iterations.
# Solving for bands 11 to 20...
# Finished solving for bands 11 to 20 after 28 iterations.
# Solving for bands 21 to 30...
# Finished solving for bands 21 to 30 after 43 iterations.
# Solving for bands 31 to 40...
# Finished solving for bands 31 to 40 after 64 iterations.
# Solving for bands 41 to 50...
# Finished solving for bands 41 to 50 after 43 iterations.
# Finished k-point with 42 mean iterations/band.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.141421, 0.0904175, 0.0904324, 0.0904324, 0.0944519, 0.189759, 0.189759, 0.189759, 0.18976, 0.189762, 0.18993, 0.189929, 0.202873, 0.236531, 0.236628, 0.236628, 0.240152, 0.245242, 0.245242, 0.245243, 0.256493, 0.266399, 0.266424, 0.266424, 0.278594, 0.376946, 0.4236, 0.42361, 0.426364, 0.426365, 0.459878, 0.459871, 0.459872, 0.459882, 0.459888, 0.462253, 0.462254, 0.465222, 0.465272, 0.46901, 0.469011, 0.469266, 0.473937, 0.47948, 0.47948, 0.489523, 0.498232, 0.498233, 0.510407, 0.511411, 0.511411
# elapsed time for k point: 44.654507637023926
# total elapsed time for run: 44.78243660926819
# done

# %%
mpb.output_efield_z(ms,25)
# Out:
# Outputting fields to e.k01.b25.z.tm.h5...

# %%
ms.get_dfield(25)  # compute the D field for band 25
ms.compute_field_energy()  # compute the energy density from D
c = mp.Cylinder(1.0, material=mp.air)
print("energy in cylinder: {}".format(ms.compute_energy_in_objects([c])))
# Out:
# D-energy-components:, 1, 25, 0, 0, 1
# energy in cylinder: 0.6264485251071318

# %%
ms.num_bands = 1  # only need to compute a single band, now!
ms.target_freq = (0.2812 + 0.4174) / 2
ms.tolerance = 1e-8

# %%
ms.run_tm()
# Out:
# Initializing eigensolver data
# Computing 1 bands with 1e-08 tolerance
# Target frequency is 0.3493
# Working in 2 dimensions.
# Grid size is 160 x 160 x 1.
# Solving for 1 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (5, 0, 0)
#      (0, 5, 0)
#      (0, 0, 1)
# Cell volume = 25
# Reciprocal lattice vectors (/ 2 pi):
#      (0.2, -0, 0)
#      (-0, 0.2, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (2,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,-1,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (2,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (1,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-1,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-2,-2,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 5 and 33 object nodes (vs. 26 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.042032718658447266
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 1...
# Finished solving for bands 1 to 1 after 325 iterations.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.141421, 0.376946
# elapsed time for k point: 11.99793028831482
# total elapsed time for run: 12.040247678756714
# done
